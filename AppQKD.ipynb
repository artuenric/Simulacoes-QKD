# %% [markdown]
# ## Requisições de Aplicações QKD

# %%
# Componentes básicos da rede
from components import Network, Controller
# Funções auxiliares para executar as aplicações
from components.qkd.app import *

# %%
# Criando uma rede:
rede = Network()

# Definindo a topologia
rows = 4
cols = 5
rede.set_lattice_topology(rows, cols)

# Definindo um controlador
controlador = Controller()
controlador.set_network(rede)

# %%
# Visualizando a topologia da rede
rede.draw()

# %%
# Critérios para requisições
num_request = 100
diff_nodes = 5
key_size = 10

# %%
# Criando uma função para gerar requisições aleatórias de qkd
def generate_qkd_request(rede, num_requests, diff_nodes=5):
        """
        Gera uma lista de requisições aleatórias de QKD.

        Args:
            num_requests (int): Número de requisições.
            diff_nodes (int): Número entre os nós. Defauts to 5.

        Returns:
            requests (list): Lista com requisições.
        """
        requests = []
        avaliable_apps = ["BB84", "E91", "B92"]
        
        for i in range(num_requests):
            alice, bob = rede.random_alice_bob(diff_nodes)
            app = random.choice(avaliable_apps)
            requests.append((alice, bob, app))
        
        return requests

# %%
# Gerando requisições aleatórias
requests = generate_qkd_request(rede, num_request, diff_nodes)
print(requests)
# Out:
# [(4, 9, 'B92'), (15, 0, 'E91'), (13, 18, 'BB84'), (14, 19, 'B92'), (4, 9, 'B92'), (4, 9, 'B92'), (5, 10, 'BB84'), (6, 11, 'E91'), (1, 6, 'E91'), (16, 1, 'B92'), (11, 16, 'E91'), (3, 8, 'E91'), (4, 9, 'BB84'), (17, 2, 'E91'), (5, 10, 'E91'), (6, 11, 'B92'), (10, 15, 'E91'), (12, 17, 'B92'), (9, 14, 'E91'), (10, 15, 'B92'), (8, 13, 'B92'), (17, 2, 'E91'), (16, 1, 'BB84'), (3, 8, 'B92'), (19, 4, 'BB84'), (9, 14, 'B92'), (10, 15, 'E91'), (10, 15, 'BB84'), (6, 11, 'BB84'), (6, 11, 'E91'), (17, 2, 'E91'), (6, 11, 'E91'), (2, 7, 'E91'), (15, 0, 'E91'), (18, 3, 'BB84'), (12, 17, 'E91'), (6, 11, 'BB84'), (14, 19, 'B92'), (8, 13, 'E91'), (10, 15, 'E91'), (17, 2, 'E91'), (13, 18, 'BB84'), (2, 7, 'B92'), (18, 3, 'B92'), (4, 9, 'BB84'), (15, 0, 'E91'), (16, 1, 'BB84'), (13, 18, 'E91'), (12, 17, 'BB84'), (6, 11, 'B92'), (7, 12, 'BB84'), (19, 4, 'E91'), (14, 19, 'B92'), (13, 18, 'BB84'), (8, 13, 'B92'), (2, 7, 'BB84'), (2, 7, 'B92'), (17, 2, 'BB84'), (7, 12, 'B92'), (5, 10, 'E91'), (10, 15, 'E91'), (19, 4, 'BB84'), (19, 4, 'E91'), (9, 14, 'B92'), (8, 13, 'E91'), (15, 0, 'BB84'), (11, 16, 'B92'), (16, 1, 'B92'), (12, 17, 'BB84'), (10, 15, 'BB84'), (14, 19, 'B92'), (5, 10, 'BB84'), (19, 4, 'BB84'), (2, 7, 'BB84'), (9, 14, 'B92'), (18, 3, 'BB84'), (5, 10, 'E91'), (14, 19, 'BB84'), (19, 4, 'BB84'), (6, 11, 'BB84'), (15, 0, 'E91'), (11, 16, 'BB84'), (8, 13, 'BB84'), (0, 5, 'B92'), (1, 6, 'E91'), (18, 3, 'B92'), (11, 16, 'BB84'), (6, 11, 'E91'), (12, 17, 'BB84'), (9, 14, 'E91'), (11, 16, 'BB84'), (10, 15, 'B92'), (8, 13, 'B92'), (19, 4, 'B92'), (14, 19, 'B92'), (17, 2, 'E91'), (8, 13, 'BB84'), (19, 4, 'E91'), (4, 9, 'BB84'), (13, 18, 'BB84')]

# %%
# Realizanod as requisições
controlador.send_requests(requests)
# Out:
# 1ª execução.
# Rotas alocadas: [[4, 9], [15, 10, 5, 0], [13, 18], [14, 19], [5, 10], [6, 11], [1, 6], [16, 11, 6, 1], [11, 16], [3, 8], [17, 12, 7, 2], [10, 15], [12, 17], [9, 14], [8, 13], [17, 12, 7, 2], [19, 14, 9, 4], [10, 15], [6, 11], [2, 7], [18, 13, 8, 3], [7, 12], [0, 5]]
# Apps: ['B92', 'E91', 'BB84', 'B92', 'BB84', 'E91', 'E91', 'B92', 'E91', 'E91', 'E91', 'E91', 'B92', 'E91', 'B92', 'E91', 'BB84', 'E91', 'E91', 'E91', 'BB84', 'BB84', 'B92']
# 2ª execução.
# Rotas alocadas: [[4, 9], [5, 10], [6, 11], [10, 15], [16, 11, 6, 1], [3, 8], [9, 14], [17, 12, 7, 2], [15, 10, 5, 0], [12, 17], [14, 19], [8, 13], [17, 12, 7, 2], [13, 18], [2, 7], [18, 13, 8, 3], [15, 10, 5, 0], [19, 14, 9, 4], [7, 12], [5, 10], [11, 16], [1, 6]]
# Apps: ['B92', 'E91', 'B92', 'B92', 'BB84', 'B92', 'B92', 'E91', 'E91', 'E91', 'B92', 'E91', 'E91', 'BB84', 'B92', 'B92', 'E91', 'E91', 'B92', 'E91', 'B92', 'E91']
# 3ª execução.
# Rotas alocadas: [[4, 9], [10, 15], [6, 11], [16, 11, 6, 1], [13, 18], [12, 17], [14, 19], [8, 13], [2, 7], [17, 12, 7, 2], [19, 14, 9, 4], [9, 14], [15, 10, 5, 0], [5, 10], [18, 13, 8, 3], [11, 16]]
# Apps: ['B92', 'BB84', 'BB84', 'BB84', 'E91', 'BB84', 'B92', 'B92', 'BB84', 'BB84', 'BB84', 'B92', 'BB84', 'BB84', 'BB84', 'BB84']
# 4ª execução.
# Rotas alocadas: [[4, 9], [6, 11], [10, 15], [13, 18], [2, 7], [10, 15], [19, 14, 9, 4], [8, 13], [16, 11, 6, 1], [12, 17], [14, 19], [9, 14], [5, 10], [15, 10, 5, 0], [18, 13, 8, 3], [11, 16], [6, 11], [17, 12, 7, 2], [19, 14, 9, 4]]
# Apps: ['BB84', 'E91', 'E91', 'BB84', 'B92', 'E91', 'E91', 'E91', 'B92', 'BB84', 'B92', 'B92', 'E91', 'E91', 'B92', 'BB84', 'E91', 'E91', 'E91']
# 5ª execução.
# Rotas alocadas: [[6, 11], [4, 9], [10, 15], [19, 14, 9, 4], [2, 7], [14, 19], [8, 13], [12, 17], [9, 14], [11, 16], [13, 18]]
# Apps: ['BB84', 'BB84', 'BB84', 'BB84', 'BB84', 'BB84', 'BB84', 'BB84', 'E91', 'BB84', 'BB84']
# 6ª execução.
# Rotas alocadas: [[6, 11], [19, 14, 9, 4], [10, 15], [8, 13], [14, 19], [4, 9]]
# Apps: ['B92', 'BB84', 'B92', 'B92', 'B92', 'BB84']
# 7ª execução.
# Rotas alocadas: [[6, 11], [19, 14, 9, 4], [8, 13]]
# Apps: ['BB84', 'B92', 'BB84']
