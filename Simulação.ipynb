# %%
from QKDnet.components import Network, Controller
from QKDnet.sim import Simulation
# Out:
# Importando Qubit
# Importando EPR

# %%
# Rede
rede = Network()
rede.set_topology("China")
rede.set_nqubits(1000)
rede.set_fidelity(0.9)
rede.draw()

# Controlador
controlador = Controller(rede)

# %%
# Simulação
sim = Simulation(rede, controlador)
sim.n_simulations = 1
sim.n_requests = 2
sim.case = 1
sim.run()
# Out:
# 2024-03-07 20:43:45,513 - Requisições recebidas pelo Controlador: [{'Num ID': 0, 'App': 'B92', 'Priority': 2, 'Keys Need': 500, 'Alice e Bob': '18-13'}, {'Num ID': 1, 'App': 'B92', 'Priority': 2, 'Keys Need': 100, 'Alice e Bob': '18-23'}]
# 2024-03-07 20:43:45,514 - Requisições ordenadas por tempo estimado: [(1, 1.025), (0, 1.125)]
# 2024-03-07 20:43:45,515 - Request: 1 - Rotas: [[18, 'TR-1', 23]]
# 2024-03-07 20:43:45,515 - Capacidade da rota [18, 'TR-1', 23]: [3, 1].
# 2024-03-07 20:43:45,516 - Load da rota [18, 'TR-1', 23]: [0, 0].
# 2024-03-07 20:43:45,516 - Request: 1 - Rota [18, 'TR-1', 23].
# 2024-03-07 20:43:45,516 - Request: 1 - Adicionado requests na lista de requests atuais.
# 2024-03-07 20:43:45,517 - Add Load na rota: [1, 1]
# 2024-03-07 20:43:45,518 - Request: 0 - Rotas: [[18, 'TR-1', 'TR-3', 'OS-3', 13]]
# 2024-03-07 20:43:45,518 - Capacidade da rota [18, 'TR-1', 'TR-3', 'OS-3', 13]: [3, 2, 3, 3].
# 2024-03-07 20:43:45,519 - Load da rota [18, 'TR-1', 'TR-3', 'OS-3', 13]: [1, 0, 0, 0].
# 2024-03-07 20:43:45,519 - Request: 0 - Rota [18, 'TR-1', 'TR-3', 'OS-3', 13].
# 2024-03-07 20:43:45,519 - Request: 0 - Adicionado requests na lista de requests atuais.
# 2024-03-07 20:43:45,520 - Add Load na rota: [2, 1, 1, 1]
# 2024-03-07 20:43:45,520 - Requests escolhidas para alocação: [1, 0]
# 2024-03-07 20:43:45,520 - Requests sendo atendidas: [1, 0]
# 2024-03-07 20:43:45,521 - Request: 1 - Executando.
# 2024-03-07 20:43:45,525 - Request: 1 - Chaves Obtidas: 259
# 2024-03-07 20:43:45,527 - Request: 1 - Chaves necessárias: -159
# 2024-03-07 20:43:45,527 - Request: 1 - Atendida com sucesso.
# 2024-03-07 20:43:45,528 - Request: 1 - Removida da lista de requests.
# 2024-03-07 20:43:45,528 - Request: 0 - Executando.
# 2024-03-07 20:43:45,533 - Request: 0 - Chaves Obtidas: 249
# 2024-03-07 20:43:45,534 - Request: 0 - Chaves necessárias: 251
# 2024-03-07 20:43:45,534 - Request: 0 - Expirou!
# 2024-03-07 20:43:45,535 - Tempo atual: 1
