# %%
from QKDnet.components import Network, Controller
from QKDnet.sim import Simulation
# Out:
# Importando Qubit
# Importando EPR

# %%
# Rede
rede = Network()
rede.set_topology("China")
rede.set_nqubits(100)
rede.set_fidelity(0.9)
rede.draw()

# Controlador
controlador = Controller(rede)

# %%
# Simulação
sim = Simulation(rede, controlador)
sim.n_simulations = 10
sim.n_requests = 5
sim.case = 1
sim.run()
# Out:
# ['B92', 'B92', 'E91', 'B92', 'BB84']
# Chaves obtidas: 80
# Chaves obtidas: 60
# Chaves obtidas: 469
# ['B92', 'B92']
# Chaves obtidas: 59
# Chaves obtidas: 24
# Chaves obtidas: 435
# Chaves obtidas: 81
# ['B92']
# Chaves obtidas: 36
# Chaves obtidas: -17
# Request atendida por completo.
# Chaves obtidas: 397
# Chaves obtidas: 53
# Chaves obtidas: 473
# ['E91', 'E91', 'E91', 'E91', 'E91']
# Chaves obtidas: 9
# Chaves obtidas: 359
# Chaves obtidas: 25
# Chaves obtidas: 446
# Chaves obtidas: 61
# ['E91', 'E91', 'E91', 'E91']
# Chaves obtidas: -14
# Request atendida por completo.
# Chaves obtidas: 325
# Chaves obtidas: -3
# Request atendida por completo.
# Chaves obtidas: 421
# Chaves obtidas: 27
# Chaves obtidas: 205
# ['E91', 'E91', 'E91']
# Chaves obtidas: 290
# Chaves obtidas: 401
# Chaves obtidas: -16
# Request atendida por completo.
# Chaves obtidas: 178
# ['E91', 'E91', 'E91']
# Chaves obtidas: 244
# Chaves obtidas: 375
# Chaves obtidas: 140
# ['E91', 'E91', 'E91']
# Chaves obtidas: 206
# Chaves obtidas: 351
# Chaves obtidas: 107
# ['E91', 'E91', 'E91']
# Chaves obtidas: 171
# Chaves obtidas: 331
# Chaves obtidas: 77
# ['E91', 'E91', 'E91']
# Chaves obtidas: 140
# Chaves obtidas: 302
# Chaves obtidas: 42
# ['E91', 'E91', 'E91']
# Chaves obtidas: 93
# Chaves obtidas: 282
# Chaves obtidas: 12
# ['E91', 'E91', 'E91']
# Chaves obtidas: 59
# Chaves obtidas: 256
# Chaves obtidas: -27
# Request atendida por completo.
# ['E91', 'E91', 'E91']
# Chaves obtidas: 26
# Chaves obtidas: 236
# ['E91', 'E91', 'E91']
# Chaves obtidas: -9
# Request atendida por completo.
# Chaves obtidas: 203
# ['E91', 'E91', 'E91']
# Chaves obtidas: 176
# ['E91', 'E91', 'E91']
# Chaves obtidas: 146
# ['E91', 'E91', 'E91']
# Chaves obtidas: 123
# ['E91', 'E91', 'E91']
# Chaves obtidas: 99
# ['E91', 'E91', 'E91']
# Chaves obtidas: 73
# ['E91', 'E91', 'E91']
# Chaves obtidas: 48
# ['E91', 'E91', 'E91']
# Chaves obtidas: 24
# ['E91', 'E91', 'E91']
# Chaves obtidas: 0
# Request atendida por completo.
# ['E91', 'E91', 'E91']
# ['E91', 'E91', 'E91']
# ['E91', 'E91', 'E91']
# ['E91', 'E91', 'E91']
# ['E91', 'E91', 'E91']
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 6
#       4 sim.n_requests = 5
#       5 sim.case = 1
# ----> 6 sim.run()
#
# File c:\Users\artue\Documents\GitHub\Simulacoes-QKD\QKDnet\sim\simulation.py:95, in Simulation.run(self)
#      93 requests = self.generate_requests()
#      94 # Envia as requisições para a rede
# ---> 95 self.controller.send_requests(requests)
#
# File c:\Users\artue\Documents\GitHub\Simulacoes-QKD\QKDnet\components\controller.py:143, in Controller.send_requests(self, requests)
#     136         request.served = True
#     138     #elif request.current_time == request.max_time:
#     139     #    print("Request NÃO atendida.")
#     140     #    self.current_requests.remove(request)
#     141     #    request.served = False
# --> 143 sleep(2)
#     144 # Atualiza o tempo de atendimento
#     145 self.update_time()
#
# KeyboardInterrupt:
