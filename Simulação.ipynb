# %%
from QKDnet.components import Network, Controller
from QKDnet.sim import Simulation
# Out:
# Importando Qubit
# Importando EPR

# %%
# Rede
rede = Network()
rede.set_topology("China")
rede.set_nqubits(1000)
rede.set_fidelity(0.9)
rede.draw()

# Controlador
controlador = Controller(rede)

# %%
# Simulação
sim = Simulation(rede, controlador)
sim.n_simulations = 1
sim.n_requests = 2
sim.case = 1
sim.run()
# Out:
# 2024-03-07 19:36:00,832 - Capacidade da rota [25, 'TR-1', 19]: [1, 2]
# 2024-03-07 19:36:00,833 - Rota [25, 'TR-1', 19] alocada para a requisição 0.
# 2024-03-07 19:36:00,833 - Adicionando request 0 na lista de requests atuais.
# 2024-03-07 19:36:00,834 - Load da rota: [0, 0]
# 2024-03-07 19:36:00,834 - Capacidade da rota [29, 'TR-2', 'TR-1', 24]: [2, 3, 3]
# 2024-03-07 19:36:00,835 - Rota [29, 'TR-2', 'TR-1', 24] alocada para a requisição 1.
# 2024-03-07 19:36:00,835 - Adicionando request 1 na lista de requests atuais.
# 2024-03-07 19:36:00,835 - Load da rota: [0, 0, 0]
# 2024-03-07 19:36:00,845 - Capacidade da rota [25, 'TR-1', 19]: [1, 2]
# 2024-03-07 19:36:00,845 - Rota [25, 'TR-1', 19] alocada para a requisição 0.
# 2024-03-07 19:36:00,846 - Adicionando request 0 na lista de requests atuais.
# 2024-03-07 19:36:00,846 - Load da rota: [0, 0]
# Requests sendo atendidas:  [0, 1]
# Request 0 sendo atendida.
# Chaves Necessárias para finalizar a App: 88
# Chaves Obtidas: 412
# Request 1 sendo atendida.
# Chaves Necessárias para finalizar a App: -130
# Chaves Obtidas: 230
# Removendo request 1 da lista de requests.
# Requests: [0, 1]
# R E M O V I a request da lista de requests. [0]
# Requests sendo atendidas:  [0]
# Request 0 sendo atendida.
# Chaves Necessárias para finalizar a App: -318
# Chaves Obtidas: 406
# Removendo request 0 da lista de requests.
# Requests: [0]
# R E M O V I a request da lista de requests. []
