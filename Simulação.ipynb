# %%
from QKDnet.components import Network, Controller
from QKDnet.sim import Simulation

# %%
# Rede
rede = Network()
rede.set_topology("China")
rede.set_nqubits(1000)
rede.set_fidelity(0.9)
rede.draw()

# Controlador
controlador = Controller(rede)

# %%
# Simulação
sim = Simulation(rede, controlador)
sim.n_simulations = 1
sim.n_requests = 2
sim.case = 1
sim.run()
# Out:
# 2024-03-11 15:22:35,842 - Requisições recebidas pelo Controlador: [{'Num ID': 0, 'App': 'E91', 'Priority': 3, 'Keys Need': 100, 'Alice e Bob': '10-11'}, {'Num ID': 1, 'App': 'B92', 'Priority': 2, 'Keys Need': 1000, 'Alice e Bob': '5-32'}]
# 2024-03-11 15:22:35,842 - Requisições ordenadas por tempo estimado: [(1, 1.25), (0, 1.05)]
# 2024-03-11 15:22:35,843 - Request: 1 - Rotas: [[5, 'OS-1', 'TR-2', 32]]
# 2024-03-11 15:22:35,844 - Capacidade da rota [5, 'OS-1', 'TR-2', 32]: [1, 2, 1].
# 2024-03-11 15:22:35,844 - Load da rota [5, 'OS-1', 'TR-2', 32]: [0, 0, 0].
# 2024-03-11 15:22:35,845 - Request: 1 - Rota [5, 'OS-1', 'TR-2', 32].
# 2024-03-11 15:22:35,845 - Request: 1 - Adicionado requests na lista de requests atuais.
# 2024-03-11 15:22:35,846 - Add Load na rota: [1, 1, 1]
# 2024-03-11 15:22:35,846 - Request: 0 - Rotas: [[10, 'OS-3', 11]]
# 2024-03-11 15:22:35,847 - Capacidade da rota [10, 'OS-3', 11]: [1, 1].
# 2024-03-11 15:22:35,847 - Load da rota [10, 'OS-3', 11]: [0, 0].
# 2024-03-11 15:22:35,848 - Request: 0 - Rota [10, 'OS-3', 11].
# 2024-03-11 15:22:35,848 - Request: 0 - Adicionado requests na lista de requests atuais.
# 2024-03-11 15:22:35,848 - Add Load na rota: [1, 1]
# 2024-03-11 15:22:35,849 - Requests escolhidas para alocação: [1, 0]
# 2024-03-11 15:22:35,849 - Requests sendo atendidas: [1, 0]
# 2024-03-11 15:22:35,850 - Request: 1 - Executando.
# 2024-03-11 15:22:35,855 - Request: 1 - Chaves Obtidas: 250
# 2024-03-11 15:22:35,855 - Request: 1 - Chaves necessárias: 750
# 2024-03-11 15:22:35,855 - Request: 1 - Expirou!
# 2024-03-11 15:22:35,856 - Tempo atual: 1
# 2024-03-11 15:22:35,856 - Request: 0 - Rotas: [[10, 'OS-3', 11]]
# 2024-03-11 15:22:35,857 - Capacidade da rota [10, 'OS-3', 11]: [1, 1].
# 2024-03-11 15:22:35,858 - Load da rota [10, 'OS-3', 11]: [1, 1].
# 2024-03-11 15:22:35,859 - Requests escolhidas para alocação: [0]
# 2024-03-11 15:22:35,859 - Requests sendo atendidas: [0]
# 2024-03-11 15:22:35,859 - Request: 0 - Executando.
# 2024-03-11 15:22:35,864 - Request: 0 - Chaves Obtidas: 404
# 2024-03-11 15:22:35,866 - Request: 0 - Chaves necessárias: -304
# 2024-03-11 15:22:35,866 - Request: 0 - Atendida com sucesso.
# 2024-03-11 15:22:35,867 - Request: 0 - Removida da lista de requests.
# 2024-03-11 15:22:35,867 - Tempo atual: 2
