# %%
from QKDnet.components import Network, Controller
from QKDnet.sim import Simulation
# Out:
# Importando Qubit
# Importando EPR

# %%
# Rede
rede = Network()
rede.set_topology("Lattice", 3, 4)
rede.set_nqubits(100)
rede.set_fidelity(0.9)
rede.draw()

# Controlador
controlador = Controller(rede)

# %%
# Simulação
sim = Simulation(rede, controlador)
sim.n_simulations = 1
sim.n_requests = 2
sim.case = 1
sim.run()
# Out:
# 2024-03-11 17:28:29,776 - Requisições recebidas pelo Controlador: [{'Num ID': 0, 'App': 'BB84', 'Priority': 5, 'Keys Need': 100, 'Alice e Bob': '2-10'}, {'Num ID': 1, 'App': 'BB84', 'Priority': 5, 'Keys Need': 100, 'Alice e Bob': '1-11'}]
# 2024-03-11 17:28:29,777 - Requisições ordenadas por tempo estimado: [(0, 3.5), (1, 3.5)]
# 2024-03-11 17:28:29,777 - Request: 0 - Rotas: [[2, 6, 10]]
# 2024-03-11 17:28:29,777 - Capacidade da rota [2, 6, 10]: [2, 3].
# 2024-03-11 17:28:29,778 - Load da rota [2, 6, 10]: [0, 0].
# 2024-03-11 17:28:29,779 - Request: 0 - Rota [2, 6, 10].
# 2024-03-11 17:28:29,779 - Request: 0 - Adicionado requests na lista de requests atuais.
# 2024-03-11 17:28:29,780 - Add Load na rota: [1, 1]
# 2024-03-11 17:28:29,781 - Request: 1 - Rotas: [[1, 5, 9, 10, 11], [1, 5, 6, 10, 11], [1, 2, 6, 10, 11], [1, 5, 6, 7, 11], [1, 2, 6, 7, 11], [1, 2, 3, 7, 11]]
# 2024-03-11 17:28:29,781 - Capacidade da rota [1, 5, 9, 10, 11]: [3, 1, 2, 3].
# 2024-03-11 17:28:29,782 - Load da rota [1, 5, 9, 10, 11]: [0, 0, 0, 0].
# 2024-03-11 17:28:29,782 - Request: 1 - Rota [1, 5, 9, 10, 11].
# 2024-03-11 17:28:29,782 - Request: 1 - Adicionado requests na lista de requests atuais.
# 2024-03-11 17:28:29,783 - Add Load na rota: [1, 1, 1, 1]
# 2024-03-11 17:28:29,783 - Requests escolhidas para alocação: [0, 1]
# 2024-03-11 17:28:29,783 - Requests sendo atendidas: [0, 1]
# 2024-03-11 17:28:29,784 - Request: 0 - Executando.
# 2024-03-11 17:28:29,785 - Request: 0 - Chaves Obtidas: 38
# 2024-03-11 17:28:29,785 - Request: 0 - Chaves necessárias: 62
# 2024-03-11 17:28:29,786 - Request: 1 - Executando.
# 2024-03-11 17:28:29,786 - Request: 1 - Chaves Obtidas: 38
# 2024-03-11 17:28:29,787 - Request: 1 - Chaves necessárias: 62
# 2024-03-11 17:28:29,787 - Tempo atual: 1
# 2024-03-11 17:28:29,788 - Request: 0 - Rotas: [[2, 6, 10]]
# 2024-03-11 17:28:29,788 - Capacidade da rota [2, 6, 10]: [2, 3].
# 2024-03-11 17:28:29,789 - Load da rota [2, 6, 10]: [0, 0].
# 2024-03-11 17:28:29,789 - Request: 0 - Rota [2, 6, 10].
# 2024-03-11 17:28:29,789 - Request: 0 - Adicionado requests na lista de requests atuais.
# 2024-03-11 17:28:29,790 - Add Load na rota: [1, 1]
# 2024-03-11 17:28:29,791 - Request: 1 - Rotas: [[1, 5, 9, 10, 11], [1, 5, 6, 10, 11], [1, 2, 6, 10, 11], [1, 5, 6, 7, 11], [1, 2, 6, 7, 11], [1, 2, 3, 7, 11]]
# 2024-03-11 17:28:29,791 - Capacidade da rota [1, 5, 9, 10, 11]: [3, 1, 2, 3].
# 2024-03-11 17:28:29,792 - Load da rota [1, 5, 9, 10, 11]: [0, 0, 0, 0].
# 2024-03-11 17:28:29,792 - Request: 1 - Rota [1, 5, 9, 10, 11].
# 2024-03-11 17:28:29,792 - Request: 1 - Adicionado requests na lista de requests atuais.
# 2024-03-11 17:28:29,793 - Add Load na rota: [1, 1, 1, 1]
# 2024-03-11 17:28:29,793 - Requests escolhidas para alocação: [0, 1]
# 2024-03-11 17:28:29,794 - Requests sendo atendidas: [0, 1]
# 2024-03-11 17:28:29,795 - Request: 0 - Executando.
# 2024-03-11 17:28:29,795 - Request: 0 - Chaves Obtidas: 41
# 2024-03-11 17:28:29,796 - Request: 0 - Chaves necessárias: 21
# 2024-03-11 17:28:29,796 - Request: 1 - Executando.
# 2024-03-11 17:28:29,797 - Request: 1 - Chaves Obtidas: 33
# 2024-03-11 17:28:29,798 - Request: 1 - Chaves necessárias: 29
# 2024-03-11 17:28:29,798 - Tempo atual: 2
# 2024-03-11 17:28:29,799 - Request: 0 - Rotas: [[2, 6, 10]]
# 2024-03-11 17:28:29,799 - Capacidade da rota [2, 6, 10]: [2, 3].
# 2024-03-11 17:28:29,799 - Load da rota [2, 6, 10]: [0, 0].
# 2024-03-11 17:28:29,800 - Request: 0 - Rota [2, 6, 10].
# 2024-03-11 17:28:29,801 - Request: 0 - Adicionado requests na lista de requests atuais.
# 2024-03-11 17:28:29,802 - Add Load na rota: [1, 1]
# 2024-03-11 17:28:29,802 - Request: 1 - Rotas: [[1, 5, 9, 10, 11], [1, 5, 6, 10, 11], [1, 2, 6, 10, 11], [1, 5, 6, 7, 11], [1, 2, 6, 7, 11], [1, 2, 3, 7, 11]]
# 2024-03-11 17:28:29,803 - Capacidade da rota [1, 5, 9, 10, 11]: [3, 1, 2, 3].
# 2024-03-11 17:28:29,803 - Load da rota [1, 5, 9, 10, 11]: [0, 0, 0, 0].
# 2024-03-11 17:28:29,804 - Request: 1 - Rota [1, 5, 9, 10, 11].
# 2024-03-11 17:28:29,804 - Request: 1 - Adicionado requests na lista de requests atuais.
# 2024-03-11 17:28:29,805 - Add Load na rota: [1, 1, 1, 1]
# 2024-03-11 17:28:29,805 - Requests escolhidas para alocação: [0, 1]
# 2024-03-11 17:28:29,806 - Requests sendo atendidas: [0, 1]
# 2024-03-11 17:28:29,806 - Request: 0 - Executando.
# 2024-03-11 17:28:29,807 - Request: 0 - Chaves Obtidas: 40
# 2024-03-11 17:28:29,808 - Request: 0 - Chaves necessárias: -19
# 2024-03-11 17:28:29,808 - Request: 0 - Atendida com sucesso.
# 2024-03-11 17:28:29,809 - Request: 1 - Executando.
# 2024-03-11 17:28:29,810 - Request: 1 - Chaves Obtidas: 44
# 2024-03-11 17:28:29,811 - Request: 1 - Chaves necessárias: -15
# 2024-03-11 17:28:29,811 - Request: 1 - Atendida com sucesso.
# 2024-03-11 17:28:29,813 - Tempo atual: 3

# %%
# Rede
rede = Network()
rede.set_topology("China")
rede.set_nqubits(100)
rede.set_fidelity(0.9)
rede.draw()

# Controlador
controlador = Controller(rede)
