# %% [markdown]
# ## Teste de Request como objeto

# %%
# Dependências
from components import Network, Controller
from components.qkd.app import *
import numpy as np

# %%
rede = Network()
rede.set_topology("Lattice", 3, 3)
controlador = Controller(rede)
rede.draw()

# %%
# Exemplo de uso
n_simulacoes = 5
n_requests = 5
apps = ["BB84", "B92", "E91"]
routes_calculation_type = "shortest"

# %%
run_simulations_object(rede, controlador, n_simulacoes, n_requests, apps, routes_calculation_type)
# Out:
# Simulação:  0
# 1ª EXECUÇÃO:
# Requisições:  ['B92: 5-3 (P:4 Key: 100)', 'B92: 5-2 (P:3 Key: 100)', 'B92: 6-8 (P:3 Key: 100)', 'B92: 0-7 (P:5 Key: 100)', 'E91: 4-7 (P:4 Key: 100)']
# Requests ordenados por prioridade:  ['B92: 0-7 (P:5 Key: 100)', 'B92: 5-3 (P:4 Key: 100)', 'E91: 4-7 (P:4 Key: 100)', 'B92: 5-2 (P:3 Key: 100)', 'B92: 6-8 (P:3 Key: 100)']
# Rotas: [[0, 3, 6, 7], [0, 3, 4, 7], [0, 1, 4, 7]]
# Rota atual trabalhada:  [0, 3, 6, 7]
# Rotas: [[5, 4, 3]]
# Rota atual trabalhada:  [5, 4, 3]
# Rotas: [[4, 7]]
# Rota atual trabalhada:  [4, 7]
# Rotas: [[5, 2]]
# Rota atual trabalhada:  [5, 2]
# Rotas: [[6, 7, 8]]
# Rota atual trabalhada:  [6, 7, 8]
# 2ª EXECUÇÃO:
# Requisições:  ['B92: 5-3 (P:4 Key: 74)', 'B92: 5-2 (P:3 Key: 70)', 'B92: 6-8 (P:3 Key: 100)', 'B92: 0-7 (P:5 Key: 75)', 'E91: 4-7 (P:4 Key: 45)']
# Requests ordenados por prioridade:  ['B92: 0-7 (P:5 Key: 75)', 'B92: 5-3 (P:4 Key: 74)', 'E91: 4-7 (P:4 Key: 45)', 'B92: 5-2 (P:3 Key: 70)', 'B92: 6-8 (P:3 Key: 100)']
# ...
