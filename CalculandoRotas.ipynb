# %%
# Componentes básicos da rede
from components import Network, Controller, Qubit
# Funções auxiliares para executar as aplicações
from components.qkd.app import *

import numpy as np

# %%
def generate_qkd_request(rede, num_requests, diff_nodes=5):
        """
        Gera uma lista de requisições aleatórias de QKD.

        Args:
            num_requests (int): Número de requisições.
            diff_nodes (int): Número entre os nós. Defauts to 5.

        Returns:
            requests (list): Lista com requisições.
        """
        requests = []
        avaliable_apps = ["B92"]
        
        for i in range(num_requests):
            alice, bob = rede.random_alice_bob(diff_nodes)
            
            app = random.choice(avaliable_apps)
            requests.append((alice, bob, app))
        
        return requests

# %%
rede = Network()
controlador = Controller()
controlador.set_network(rede)
rede.set_lattice_topology(3, 4)
rede.draw()

# %%
# Gerando requisições aleatórias
requests = generate_qkd_request(rede, 10, 3)
requestsCopia = requests.copy()

# %%
# Alocando rotas para os requests baseados no algoritmo de menor caminho
rota = controlador.allocate_routes(requests, 'shortest')
# Out:
# Rotas calculadas [[0, 1, 2, 3]]
# Rota avaliada [0, 1, 2, 3]
# Rotas calculadas [[2, 1, 5], [2, 6, 5]]
# Rota avaliada [2, 1, 5]
# Rotas calculadas [[9, 5, 1, 0], [9, 5, 4, 0], [9, 8, 4, 0]]
# Rota avaliada [9, 5, 1, 0]
# Rotas calculadas [[3, 2, 6], [3, 7, 6]]
# Rota avaliada [3, 2, 6]
# Rotas calculadas [[5, 4, 8], [5, 9, 8]]
# Rota avaliada [5, 4, 8]
# Rotas calculadas [[6, 5, 9], [6, 10, 9]]
# Rota avaliada [6, 5, 9]
# Rotas calculadas [[9, 5, 1, 0], [9, 5, 4, 0], [9, 8, 4, 0]]
# Rota avaliada [9, 5, 1, 0]
# Rota avaliada [9, 5, 4, 0]
# Rota avaliada [9, 8, 4, 0]
# Rotas calculadas [[9, 5, 1, 0], [9, 5, 4, 0], [9, 8, 4, 0]]
# Rota avaliada [9, 5, 1, 0]
# Rota avaliada [9, 5, 4, 0]
# Rota avaliada [9, 8, 4, 0]
# Rotas calculadas [[2, 1, 5], [2, 6, 5]]
# Rota avaliada [2, 1, 5]
# Rota avaliada [2, 6, 5]
# Rotas calculadas [[5, 4, 8], [5, 9, 8]]
# Rota avaliada [5, 4, 8]
# Rota avaliada [5, 9, 8]

# %%
# Alocando rotas para os requests baseados em todos os caminhos
rota = controlador.allocate_routes(requestsCopia, 'all')
# Out:
# Rotas calculadas [[0, 1, 2, 3], [0, 4, 5, 1, 2, 3], [0, 4, 5, 6, 2, 3], [0, 4, 5, 6, 7, 3], [0, 1, 5, 6, 2, 3], [0, 1, 5, 6, 7, 3], [0, 1, 2, 6, 7, 3], [0, 4, 8, 9, 5, 1, 2, 3], [0, 4, 8, 9, 5, 6, 2, 3], [0, 4, 8, 9, 5, 6, 7, 3], [0, 4, 8, 9, 10, 6, 2, 3], [0, 4, 8, 9, 10, 6, 7, 3], [0, 4, 8, 9, 10, 11, 7, 3], [0, 4, 5, 1, 2, 6, 7, 3], [0, 4, 5, 9, 10, 6, 2, 3], [0, 4, 5, 9, 10, 6, 7, 3], [0, 4, 5, 9, 10, 11, 7, 3], [0, 4, 5, 6, 10, 11, 7, 3], [0, 1, 5, 9, 10, 6, 2, 3], [0, 1, 5, 9, 10, 6, 7, 3], [0, 1, 5, 
# Rota avaliada [6, 5, 9]
# Rotas calculadas [[9, 5, 1, 0], [9, 5, 4, 0], [9, 8, 4, 0], [9, 5, 6, 2, 1, 0], [9, 8, 4, 5, 1, 0], [9, 10, 6, 2, 1, 0], [9, 10, 6, 5, 1, 0], [9, 10, 6, 5, 4, 0], [9, 5, 6, 7, 3, 2, 1, 0], [9, 8, 4, 5, 6, 2, 1, 0], [9, 10, 6, 2, 1, 5, 4, 0], [9, 10, 6, 7, 3, 2, 1, 0], [9, 10, 11, 7, 3, 2, 1, 0], [9, 10, 11, 7, 6, 2, 1, 0], [9, 10, 11, 7, 6, 5, 1, 0], [9, 10, 11, 7, 6, 5, 4, 0], [9, 5, 6, 10, 11, 7, 3, 2, 1, 0], [9, 8, 4, 5, 6, 7, 3, 2, 1, 0], [9, 10, 6, 7, 3, 2, 1, 5, 4, 0], [9, 10, 11, 7, 3, 2, 1, 5, 4, 0], [9, 10, 11, 7, 3, 2, 6, 5, 1, 0], [9, 10, 11, 7, 3, 2, 6, 5, 4, 0], [9, 10, 11, 7, 6, 2, 1, 5, 4, 0], [9, 8, 4, 5, 6, 10, 11, 7, 3, 2, 1, 0]]
# Rota avaliada [9, 5, 1, 0]
# Rota avaliada [9, 5, 4, 0]
# Rota avaliada [9, 8, 4, 0]
# Rotas calculadas [[9, 5, 1, 0], [9, 5, 4, 0], [9, 8, 4, 0], [9, 5, 6, 2, 1, 0], [9, 8, 4, 5, 1, 0], [9, 10, 6, 2, 1, 0], [9, 10, 6, 5, 1, 0], [9, 10, 6, 5, 4, 0], [9, 5, 6, 7, 3, 2, 1, 0], [9, 8, 4, 5, 6, 2, 1, 0], [9, 10, 6, 2, 1, 5, 4, 0], [9, 10, 6, 7, 3, 2, 1, 0], [9, 10, 11, 7, 3, 2, 1, 0], [9, 10, 11, 7, 6, 2, 1, 0], [9, 10, 11, 7, 6, 5, 1, 0], [9, 10, 11, 7, 6, 5, 4, 0], [9, 5, 6, 10, 11, 7, 3, 2, 1, 0], [9, 8, 4, 5, 6, 7, 3, 2, 1, 0], [9, 10, 6, 7, 3, 2, 1, 5, 4, 0], [9, 10, 11, 7, 3, 2, 1, 5, 4, 0], [9, 10, 11, 7, 3, 2, 6, 5, 1, 0], [9, 10, 11, 7, 3, 2, 6, 5, 4, 0], [9, 10, 11, 7, 6, 2, 1, 5, 4, 0], [9, 8, 4, 5, 6, 10, 11, 7, 3, 2, 1, 0]]
# Rota avaliada [9, 5, 1, 0]
# Rota avaliada [9, 5, 4, 0]
# Rota avaliada [9, 8, 4, 0]
# Rota avaliada [9, 5, 6, 2, 1, 0]
# Rota avaliada [9, 8, 4, 5, 1, 0]
# Rota avaliada [9, 10, 6, 2, 1, 0]
# Rota avaliada [9, 10, 6, 5, 1, 0]
# Rota avaliada [9, 10, 6, 5, 4, 0]
# Rota avaliada [9, 5, 6, 7, 3, 2, 1, 0]
# Rota avaliada [9, 8, 4, 5, 6, 2, 1, 0]
# Rota avaliada [9, 10, 6, 2, 1, 5, 4, 0]
# Rota avaliada [9, 10, 6, 7, 3, 2, 1, 0]
# Rota avaliada [9, 10, 11, 7, 3, 2, 1, 0]
# Rota avaliada [9, 10, 11, 7, 6, 2, 1, 0]
# Rota avaliada [9, 10, 11, 7, 6, 5, 1, 0]
# Rota avaliada [9, 10, 11, 7, 6, 5, 4, 0]
# Rota avaliada [9, 5, 6, 10, 11, 7, 3, 2, 1, 0]
# Rota avaliada [9, 8, 4, 5, 6, 7, 3, 2, 1, 0]
# Rota avaliada [9, 10, 6, 7, 3, 2, 1, 5, 4, 0]
# Rota avaliada [9, 10, 11, 7, 3, 2, 1, 5, 4, 0]
# Rota avaliada [9, 10, 11, 7, 3, 2, 6, 5, 1, 0]
# Rota avaliada [9, 10, 11, 7, 3, 2, 6, 5, 4, 0]
# Rota avaliada [9, 10, 11, 7, 6, 2, 1, 5, 4, 0]
# Rota avaliada [9, 8, 4, 5, 6, 10, 11, 7, 3, 2, 1, 0]
# Rotas calculadas [[2, 1, 5], [2, 6, 5], [2, 1, 0, 4, 5], [2, 6, 10, 9, 5], [2, 3, 7, 6, 5], [2, 1, 0, 4, 8, 9, 5], [2, 6, 10, 9, 8, 4, 5], [2, 6, 7, 11, 10, 9, 5], [2, 3, 7, 6, 10, 9, 5], [2, 3, 7, 11, 10, 6, 5], [2, 3, 7, 11, 10, 9, 5], [2, 1, 0, 4, 8, 9, 10, 6, 5], [2, 6, 10, 9, 8, 4, 0, 1, 5], [2, 6, 7, 11, 10, 9, 8, 4, 5], [2, 3, 7, 6, 10, 9, 8, 4, 5], [2, 3, 7, 11, 10, 9, 8, 4, 5], [2, 1, 0, 4, 8, 9, 10, 11, 7, 6, 5], [2, 6, 7, 11, 10, 9, 8, 4, 0, 1, 5], [2, 3, 7, 6, 10, 9, 8, 4, 0, 1, 5], [2, 3, 7, 11, 10, 9, 8, 4, 0, 1, 5]]
# Rota avaliada [2, 1, 5]
# Rota avaliada [2, 6, 5]
# Rota avaliada [2, 1, 0, 4, 5]
# Rota avaliada [2, 6, 10, 9, 5]
# Rota avaliada [2, 3, 7, 6, 5]
# Rota avaliada [2, 1, 0, 4, 8, 9, 5]
# Rota avaliada [2, 6, 10, 9, 8, 4, 5]
# Rota avaliada [2, 6, 7, 11, 10, 9, 5]
# Rota avaliada [2, 3, 7, 6, 10, 9, 5]
# Rota avaliada [2, 3, 7, 11, 10, 6, 5]
# Rota avaliada [2, 3, 7, 11, 10, 9, 5]
# Rota avaliada [2, 1, 0, 4, 8, 9, 10, 6, 5]
# Rota avaliada [2, 6, 10, 9, 8, 4, 0, 1, 5]
# Rota avaliada [2, 6, 7, 11, 10, 9, 8, 4, 5]
# Rota avaliada [2, 3, 7, 6, 10, 9, 8, 4, 5]
# Rota avaliada [2, 3, 7, 11, 10, 9, 8, 4, 5]
# Rota avaliada [2, 1, 0, 4, 8, 9, 10, 11, 7, 6, 5]
# Rota avaliada [2, 6, 7, 11, 10, 9, 8, 4, 0, 1, 5]
# Rota avaliada [2, 3, 7, 6, 10, 9, 8, 4, 0, 1, 5]
# Rota avaliada [2, 3, 7, 11, 10, 9, 8, 4, 0, 1, 5]
# Rotas calculadas [[5, 4, 8], [5, 9, 8], [5, 1, 0, 4, 8], [5, 6, 10, 9, 8], [5, 1, 2, 6, 10, 9, 8], [5, 6, 2, 1, 0, 4, 8], [5, 6, 7, 11, 10, 9, 8], [5, 1, 2, 6, 7, 11, 10, 9, 8], [5, 1, 2, 3, 7, 6, 10, 9, 8], [5, 1, 2, 3, 7, 11, 10, 9, 8], [5, 4, 0, 1, 2, 6, 10, 9, 8], [5, 9, 10, 6, 2, 1, 0, 4, 8], [5, 6, 2, 3, 7, 11, 10, 9, 8], [5, 6, 7, 3, 2, 1, 0, 4, 8], [5, 4, 0, 1, 2, 6, 7, 11, 10, 9, 8], [5, 4, 0, 1, 2, 3, 7, 6, 10, 9, 8], [5, 4, 0, 1, 2, 3, 7, 11, 10, 9, 8], [5, 9, 10, 6, 7, 3, 2, 1, 0, 4, 8], [5, 9, 10, 11, 7, 3, 2, 1, 0, 4, 8], [5, 9, 10, 11, 7, 6, 2, 1, 0, 4, 8], [5, 6, 10, 11, 7, 3, 2, 1, 0, 4, 8]]
# Rota avaliada [5, 4, 8]
# Rota avaliada [5, 9, 8]
# Rota avaliada [5, 1, 0, 4, 8]
# Rota avaliada [5, 6, 10, 9, 8]
# Rota avaliada [5, 1, 2, 6, 10, 9, 8]
# Rota avaliada [5, 6, 2, 1, 0, 4, 8]
# Rota avaliada [5, 6, 7, 11, 10, 9, 8]
# Rota avaliada [5, 1, 2, 6, 7, 11, 10, 9, 8]
# Rota avaliada [5, 1, 2, 3, 7, 6, 10, 9, 8]
# Rota avaliada [5, 1, 2, 3, 7, 11, 10, 9, 8]
# Rota avaliada [5, 4, 0, 1, 2, 6, 10, 9, 8]
# Rota avaliada [5, 9, 10, 6, 2, 1, 0, 4, 8]
# Rota avaliada [5, 6, 2, 3, 7, 11, 10, 9, 8]
# Rota avaliada [5, 6, 7, 3, 2, 1, 0, 4, 8]
# Rota avaliada [5, 4, 0, 1, 2, 6, 7, 11, 10, 9, 8]
# Rota avaliada [5, 4, 0, 1, 2, 3, 7, 6, 10, 9, 8]
# Rota avaliada [5, 4, 0, 1, 2, 3, 7, 11, 10, 9, 8]
# Rota avaliada [5, 9, 10, 6, 7, 3, 2, 1, 0, 4, 8]
# Rota avaliada [5, 9, 10, 11, 7, 3, 2, 1, 0, 4, 8]
# Rota avaliada [5, 9, 10, 11, 7, 6, 2, 1, 0, 4, 8]
# Rota avaliada [5, 6, 10, 11, 7, 3, 2, 1, 0, 4, 8]
