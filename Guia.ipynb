# %%
# Dependências
from QKDnet.components import Network, Controller

# %%
# Definindo rede e controlador
rede = Network()
rede.set_topology("China")
controlador = Controller(rede)

# Algumas propriedades da rede
rede.nqubits = 300
rede.set_fidelity(0.95)
rede.draw()

# %%
# Calculando a rota mais curta entre dois nós
route = controlador.calculate_shortest_route(1, 5) # Antigo
route = controlador.path_finder.get_paths(1, 5) # Novo
print(route)
# Out:
# [[1, 'OS-1', 5]]

# %%
# Acessando todos os enlaces da rede
rede.channels
# Out:
# {(1, 'OS-1'): {'load': 0,
#   'capacity': 1,
#   'epr_available': 1,
#   'fidelity_value': 0.95},
#  (2, 'OS-1'): {'load': 0,
#   'capacity': 1,
#   'epr_available': 1,
#   'fidelity_value': 0.95},
#  (3, 'OS-1'): {'load': 0,
#   'capacity': 1,
#   'epr_available': 2,
#   'fidelity_value': 0.95},
#  (4, 'OS-1'): {'load': 0,
#   'capacity': 1,
#   'epr_available': 1,
#   'fidelity_value': 0.95},
#  (5, 'OS-1'): {'load': 0,
#   'capacity': 1,
#   'epr_available': 2,
#   'fidelity_value': 0.95},
#  (6, 'OS-2'): {'load': 0,
#   'capacity': 1,
#   'epr_available': 2,
#   'fidelity_value': 0.95},
#  (7, 'OS-2'): {'load': 0,
#   'capacity': 1,
#   'epr_available': 2,
#   'fidelity_value': 0.95},
#  (8, 'OS-3'): {'load': 0,
#   'capacity': 1,
#   'epr_available': 1,
#   'fidelity_value': 0.95},
#  (9, 'OS-3'): {'load': 0,
#   'capacity': 1,
#   'epr_available': 1,
#   'fidelity_value': 0.95},
#  (10, 'OS-3'): {'load': 0,
#   'capacity': 1,
#   'epr_available': 2,
#   'fidelity_value': 0.95},
#  (11, 'OS-3'): {'load': 0,
#   'capacity': 1,
#   'epr_available': 1,
#   'fidelity_value': 0.95},
#  (12, 'OS-3'): {'load': 0,
#   'capacity': 1,
#   'epr_available': 1,
#   'fidelity_value': 0.95},
#  (13, 'OS-3'): {'load': 0,
#   'capacity': 1,
#   'epr_available': 1,
#   'fidelity_value': 0.95},
#  (14, 'TR-1'): {'load': 0,
#   'capacity': 1,
#   'epr_available': 2,
#   'fidelity_value': 0.95},
#  (15, 'TR-1'): {'load': 0,
#   'capacity': 1,
#   'epr_available': 1,
#   'fidelity_value': 0.95},
#  (16, 'TR-1'): {'load': 0,
#   'capacity': 1,
#   'epr_available': 1,
#   'fidelity_value': 0.95},
#  (17, 'TR-1'): {'load': 0,
#   'capacity': 1,
#   'epr_available': 1,
#   'fidelity_value': 0.95},
#  (18, 'TR-1'): {'load': 0,
#   'capacity': 1,
#   'epr_available': 1,
#   'fidelity_value': 0.95},
#  (19, 'TR-1'): {'load': 0,
#   'capacity': 1,
#   'epr_available': 1,
#   'fidelity_value': 0.95},
#  (20, 'TR-1'): {'load': 0,
#   'capacity': 1,
#   'epr_available': 1,
#   'fidelity_value': 0.95},
#  (21, 'TR-1'): {'load': 0,
#   'capacity': 1,
#   'epr_available': 1,
#   'fidelity_value': 0.95},
#  (22, 'TR-1'): {'load': 0,
#   'capacity': 1,
#   'epr_available': 2,
#   'fidelity_value': 0.95},
#  (23, 'TR-1'): {'load': 0,
#   'capacity': 1,
#   'epr_available': 1,
#   'fidelity_value': 0.95},
#  (24, 'TR-1'): {'load': 0,
#   'capacity': 1,
#   'epr_available': 2,
#   'fidelity_value': 0.95},
#  (25, 'TR-1'): {'load': 0,
#   'capacity': 1,
#   'epr_available': 1,
#   'fidelity_value': 0.95},
#  (26, 'TR-1'): {'load': 0,
#   'capacity': 1,
#   'epr_available': 2,
#   'fidelity_value': 0.95},
#  (27, 'TR-2'): {'load': 0,
#   'capacity': 1,
#   'epr_available': 2,
#   'fidelity_value': 0.95},
#  (28, 'TR-2'): {'load': 0,
#   'capacity': 1,
#   'epr_available': 1,
#   'fidelity_value': 0.95},
#  (29, 'TR-2'): {'load': 0,
#   'capacity': 1,
#   'epr_available': 2,
#   'fidelity_value': 0.95},
#  (30, 'TR-2'): {'load': 0,
#   'capacity': 1,
#   'epr_available': 1,
#   'fidelity_value': 0.95},
#  (31, 'TR-2'): {'load': 0,
#   'capacity': 1,
#   'epr_available': 2,
#   'fidelity_value': 0.95},
#  (32, 'TR-2'): {'load': 0,
#   'capacity': 1,
#   'epr_available': 2,
#   'fidelity_value': 0.95},
#  (33, 'TR-3'): {'load': 0,
#   'capacity': 1,
#   'epr_available': 2,
#   'fidelity_value': 0.95},
#  (34, 'TR-3'): {'load': 0,
#   'capacity': 1,
#   'epr_available': 1,
#   'fidelity_value': 0.95},
#  (35, 'TR-3'): {'load': 0,
#   'capacity': 1,
#   'epr_available': 1,
#   'fidelity_value': 0.95},
#  (36, 'TR-3'): {'load': 0,
#   'capacity': 1,
#   'epr_available': 1,
#   'fidelity_value': 0.95},
#  (37, 'TR-3'): {'load': 0,
#   'capacity': 1,
#   'epr_available': 2,
#   'fidelity_value': 0.95},
#  (38, 'TR-3'): {'load': 0,
#   'capacity': 1,
#   'epr_available': 1,
#   'fidelity_value': 0.95},
#  (39, 'TR-3'): {'load': 0,
#   'capacity': 1,
#   'epr_available': 2,
#   'fidelity_value': 0.95},
#  (40, 'TR-3'): {'load': 0,
#   'capacity': 1,
#   'epr_available': 1,
#   'fidelity_value': 0.95},
#  ('TR-1', 'TR-2'): {'load': 0,
#   'capacity': 1,
#   'epr_available': 1,
#   'fidelity_value': 0.95},
#  ('TR-1', 'TR-3'): {'load': 0,
#   'capacity': 1,
#   'epr_available': 2,
#   'fidelity_value': 0.95},
#  ('TR-2', 'OS-1'): {'load': 0,
#   'capacity': 1,
#   'epr_available': 2,
#   'fidelity_value': 0.95},
#  ('TR-2', 'OS-2'): {'load': 0,
#   'capacity': 1,
#   'epr_available': 1,
#   'fidelity_value': 0.95},
#  ('TR-2', 'TR-3'): {'load': 0,
#   'capacity': 1,
#   'epr_available': 2,
#   'fidelity_value': 0.95},
#  ('TR-3', 'OS-3'): {'load': 0,
#   'capacity': 1,
#   'epr_available': 2,
#   'fidelity_value': 0.95},
#  ('OS-1', 1): {'load': 0,
#   'capacity': 1,
#   'epr_available': 2,
#   'fidelity_value': 0.95},
#  ('OS-1', 2): {'load': 0,
#   'capacity': 1,
#   'epr_available': 2,
#   'fidelity_value': 0.95},
#  ('OS-1', 3): {'load': 0,
#   'capacity': 1,
#   'epr_available': 1,
#   'fidelity_value': 0.95},
#  ('OS-1', 4): {'load': 0,
#   'capacity': 1,
#   'epr_available': 2,
#   'fidelity_value': 0.95},
#  ('OS-1', 5): {'load': 0,
#   'capacity': 1,
#   'epr_available': 2,
#   'fidelity_value': 0.95},
#  ('OS-2', 6): {'load': 0,
#   'capacity': 1,
#   'epr_available': 2,
#   'fidelity_value': 0.95},
#  ('OS-2', 7): {'load': 0,
#   'capacity': 1,
#   'epr_available': 2,
#   'fidelity_value': 0.95},
#  ('OS-3', 8): {'load': 0,
#   'capacity': 1,
#   'epr_available': 1,
#   'fidelity_value': 0.95},
#  ('OS-3', 9): {'load': 0,
#   'capacity': 1,
#   'epr_available': 2,
#   'fidelity_value': 0.95},
#  ('OS-3', 10): {'load': 0,
#   'capacity': 1,
#   'epr_available': 1,
#   'fidelity_value': 0.95},
#  ('OS-3', 11): {'load': 0,
#   'capacity': 1,
#   'epr_available': 2,
#   'fidelity_value': 0.95},
#  ('OS-3', 12): {'load': 0,
#   'capacity': 1,
#   'epr_available': 1,
#   'fidelity_value': 0.95},
#  ('OS-3', 13): {'load': 0,
#   'capacity': 1,
#   'epr_available': 2,
#   'fidelity_value': 0.95},
#  ('TR-1', 14): {'load': 0,
#   'capacity': 1,
#   'epr_available': 2,
#   'fidelity_value': 0.95},
#  ('TR-1', 15): {'load': 0,
#   'capacity': 1,
#   'epr_available': 1,
#   'fidelity_value': 0.95},
#  ('TR-1', 16): {'load': 0,
#   'capacity': 1,
#   'epr_available': 2,
#   'fidelity_value': 0.95},
#  ('TR-1', 17): {'load': 0,
#   'capacity': 1,
#   'epr_available': 2,
#   'fidelity_value': 0.95},
#  ('TR-1', 18): {'load': 0,
#   'capacity': 1,
#   'epr_available': 2,
#   'fidelity_value': 0.95},
#  ('TR-1', 19): {'load': 0,
#   'capacity': 1,
#   'epr_available': 2,
#   'fidelity_value': 0.95},
#  ('TR-1', 20): {'load': 0,
#   'capacity': 1,
#   'epr_available': 1,
#   'fidelity_value': 0.95},
#  ('TR-1', 21): {'load': 0,
#   'capacity': 1,
#   'epr_available': 1,
#   'fidelity_value': 0.95},
#  ('TR-1', 22): {'load': 0,
#   'capacity': 1,
#   'epr_available': 1,
#   'fidelity_value': 0.95},
#  ('TR-1', 23): {'load': 0,
#   'capacity': 1,
#   'epr_available': 2,
#   'fidelity_value': 0.95},
#  ('TR-1', 24): {'load': 0,
#   'capacity': 1,
#   'epr_available': 2,
#   'fidelity_value': 0.95},
#  ('TR-1', 25): {'load': 0,
#   'capacity': 1,
#   'epr_available': 1,
#   'fidelity_value': 0.95},
#  ('TR-1', 26): {'load': 0,
#   'capacity': 1,
#   'epr_available': 1,
#   'fidelity_value': 0.95},
#  ('TR-2', 27): {'load': 0,
#   'capacity': 1,
#   'epr_available': 2,
#   'fidelity_value': 0.95},
#  ('TR-2', 28): {'load': 0,
#   'capacity': 1,
#   'epr_available': 1,
#   'fidelity_value': 0.95},
#  ('TR-2', 29): {'load': 0,
#   'capacity': 1,
#   'epr_available': 1,
#   'fidelity_value': 0.95},
#  ('TR-2', 30): {'load': 0,
#   'capacity': 1,
#   'epr_available': 1,
#   'fidelity_value': 0.95},
#  ('TR-2', 31): {'load': 0,
#   'capacity': 1,
#   'epr_available': 2,
#   'fidelity_value': 0.95},
#  ('TR-2', 32): {'load': 0,
#   'capacity': 1,
#   'epr_available': 1,
#   'fidelity_value': 0.95},
#  ('TR-3', 33): {'load': 0,
#   'capacity': 1,
#   'epr_available': 2,
#   'fidelity_value': 0.95},
#  ('TR-3', 34): {'load': 0,
#   'capacity': 1,
#   'epr_available': 2,
#   'fidelity_value': 0.95},
#  ('TR-3', 35): {'load': 0,
#   'capacity': 1,
#   'epr_available': 2,
#   'fidelity_value': 0.95},
#  ('TR-3', 36): {'load': 0,
#   'capacity': 1,
#   'epr_available': 2,
#   'fidelity_value': 0.95},
#  ('TR-3', 37): {'load': 0,
#   'capacity': 1,
#   'epr_available': 2,
#   'fidelity_value': 0.95},
#  ('TR-3', 38): {'load': 0,
#   'capacity': 1,
#   'epr_available': 1,
#   'fidelity_value': 0.95},
#  ('TR-3', 39): {'load': 0,
#   'capacity': 1,
#   'epr_available': 2,
#   'fidelity_value': 0.95},
#  ('TR-3', 40): {'load': 0,
#   'capacity': 1,
#   'epr_available': 2,
#   'fidelity_value': 0.95},
#  ('TR-2', 'TR-1'): {'load': 0,
#   'capacity': 1,
#   'epr_available': 1,
#   'fidelity_value': 0.95},
#  ('TR-3', 'TR-1'): {'load': 0,
#   'capacity': 1,
#   'epr_available': 2,
#   'fidelity_value': 0.95},
#  ('OS-1', 'TR-2'): {'load': 0,
#   'capacity': 1,
#   'epr_available': 1,
#   'fidelity_value': 0.95},
#  ('OS-2', 'TR-2'): {'load': 0,
#   'capacity': 1,
#   'epr_available': 1,
#   'fidelity_value': 0.95},
#  ('TR-3', 'TR-2'): {'load': 0,
#   'capacity': 1,
#   'epr_available': 1,
#   'fidelity_value': 0.95},
#  ('OS-3', 'TR-3'): {'load': 0,
#   'capacity': 1,
#   'epr_available': 1,
#   'fidelity_value': 0.95}}

# %%
# Acessando um enlace específico
rede.channels[(1, 'OS-1')]
# Out:
# {'load': 0, 'capacity': 1, 'epr_available': 1, 'fidelity_value': 0.95}

# %%
# Caso o enlace não exista
rede.channels[(1, 'OS-2')]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 2
#       1 # Caso o enlace não exista
# ----> 2 rede.channels[(1, 'OS-2')]
#
# KeyError: (1, 'OS-2')

# %%
# Acessando uma informação específica do enlace: capacity, epr_avaible, fidelity_value
rede.channels[(1, 'OS-1')]["capacity"]
# Out:
# 1

# %%
# Alterando uma informação específica do enlace: capacity, epr_avaible, fidelity_value
rede.channels[(1, 'OS-1')]["load"] = 10
rede.channels[(1, 'OS-1')]["load"]
# Out:
# 10
