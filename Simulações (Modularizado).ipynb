# %% [markdown]
# # Simulações com auxílio da função
#
# Simulações com a utilização da função ``run_simulations`` de ``components/qkd/app.py``.

# %%
# Dependências
from components import Network, Controller
from components.qkd.app import *
import numpy as np

# %%
# Criação da rede
rede = Network()
rede.set_topology("Lattice", 3, 3)
controlador = Controller(rede)
rede.draw()

# %%
# Informações da simulação
n_simulacoes = 5
n_requests = 5
caso = 0
apps = ["BB84", "B92", "E91"]
routes_calculation_type = "shortest"

# %%
vazao, taxa = run_simulations(rede, controlador, n_simulacoes, n_requests, apps, caso, routes_calculation_type)
# Out:
# Simulação:  0
# 1ª EXECUÇÃO:
# Requisições:  ['BB84: 0-1 (P:2 Key: 100)', 'B92: 1-8 (P:2 Key: 100)', 'B92: 1-7 (P:2 Key: 100)', 'B92: 5-8 (P:4 Key: 100)', 'B92: 2-8 (P:1 Key: 100)']
# Requests ordenados por prioridade:  ['B92: 5-8 (P:4 Key: 100)', 'BB84: 0-1 (P:2 Key: 100)', 'B92: 1-8 (P:2 Key: 100)', 'B92: 1-7 (P:2 Key: 100)', 'B92: 2-8 (P:1 Key: 100)']
# Rotas: [[5, 8]]
# Rota atual trabalhada:  [5, 8]
# Rotas: [[0, 1]]
# Rota atual trabalhada:  [0, 1]
# Rotas: [[1, 2, 5, 8]]
# Rota atual trabalhada:  [1, 2, 5, 8]
# Rotas: [[1, 4, 7]]
# Rota atual trabalhada:  [1, 4, 7]
# Rotas: [[2, 5, 8]]
# Rota atual trabalhada:  [2, 5, 8]
# 2ª EXECUÇÃO:
# Requisições:  ['BB84: 0-1 (P:2 Key: 13)', 'B92: 1-8 (P:2 Key: 100)', 'B92: 1-7 (P:2 Key: 55)', 'B92: 5-8 (P:4 Key: 47)', 'B92: 2-8 (P:1 Key: 100)']
# Requests ordenados por prioridade:  ['B92: 5-8 (P:4 Key: 47)', 'BB84: 0-1 (P:2 Key: 13)', 'B92: 1-8 (P:2 Key: 100)', 'B92: 1-7 (P:2 Key: 55)', 'B92: 2-8 (P:1 Key: 100)']
# Rotas: [[5, 8]]
# Rota atual trabalhada:  [5, 8]
# Rotas: [[0, 1]]
# Rota atual trabalhada:  [0, 1]
# Rotas: [[1, 2, 5, 8]]
# Rota atual trabalhada:  [1, 2, 5, 8]
# Rotas: [[1, 4, 7]]
# Rota atual trabalhada:  [1, 4, 7]
# Rotas: [[2, 5, 8]]
# Rota atual trabalhada:  [2, 5, 8]
# 3ª EXECUÇÃO:
# Requisições:  ['B92: 1-8 (P:2 Key: 100)', 'B92: 1-7 (P:2 Key: 12)', 'B92: 2-8 (P:1 Key: 100)']
# Requests ordenados por prioridade:  ['B92: 1-8 (P:2 Key: 100)', 'B92: 1-7 (P:2 Key: 12)', 'B92: 2-8 (P:1 Key: 100)']
# Rotas: [[1, 2, 5, 8]]
# Rota atual trabalhada:  [1, 2, 5, 8]
# Rotas: [[1, 4, 7]]
# Rota atual trabalhada:  [1, 4, 7]
# Rotas: [[2, 5, 8]]
# Rota atual trabalhada:  [2, 5, 8]
# 4ª EXECUÇÃO:
# Requisições:  ['B92: 1-8 (P:2 Key: 44)', 'B92: 2-8 (P:1 Key: 100)']
# Requests ordenados por prioridade:  ['B92: 1-8 (P:2 Key: 44)', 'B92: 2-8 (P:1 Key: 100)']
# Rotas: [[1, 2, 5, 8]]
# Rota atual trabalhada:  [1, 2, 5, 8]
# Rotas: [[2, 5, 8]]
# Rota atual trabalhada:  [2, 5, 8]
# 5ª EXECUÇÃO:
# Requisições:  ['B92: 2-8 (P:1 Key: 100)']
# Requests ordenados por prioridade:  ['B92: 2-8 (P:1 Key: 100)']
# Rotas: [[2, 5, 8]]
# Rota atual trabalhada:  [2, 5, 8]
# 6ª EXECUÇÃO:
# Requisições:  ['B92: 2-8 (P:1 Key: 46)']
# Requests ordenados por prioridade:  ['B92: 2-8 (P:1 Key: 46)']
# Rotas: [[2, 5, 8]]
# Rota atual trabalhada:  [2, 5, 8]
# Requests:  []
# Simulação:  1
# 1ª EXECUÇÃO:
# Requisições:  ['BB84: 2-5 (P:3 Key: 100)', 'BB84: 2-0 (P:2 Key: 100)', 'E91: 3-1 (P:2 Key: 100)', 'B92: 8-4 (P:2 Key: 100)', 'E91: 4-1 (P:2 Key: 100)']
# Requests ordenados por prioridade:  ['BB84: 2-5 (P:3 Key: 100)', 'BB84: 2-0 (P:2 Key: 100)', 'E91: 3-1 (P:2 Key: 100)', 'B92: 8-4 (P:2 Key: 100)', 'E91: 4-1 (P:2 Key: 100)']
# Rotas: [[2, 5]]
# Rota atual trabalhada:  [2, 5]
# Rotas: [[2, 1, 0]]
# Rota atual trabalhada:  [2, 1, 0]
# Rotas: [[3, 0, 1]]
# Rota atual trabalhada:  [3, 0, 1]
# Rotas: [[8, 7, 4]]
# Rota atual trabalhada:  [8, 7, 4]
# Rotas: [[4, 1]]
# Rota atual trabalhada:  [4, 1]
# 2ª EXECUÇÃO:
# Requisições:  ['BB84: 2-5 (P:3 Key: 1)', 'BB84: 2-0 (P:2 Key: 8)', 'E91: 3-1 (P:2 Key: 15)', 'B92: 8-4 (P:2 Key: 51)', 'E91: 4-1 (P:2 Key: 6)']
# Requests ordenados por prioridade:  ['BB84: 2-5 (P:3 Key: 1)', 'BB84: 2-0 (P:2 Key: 8)', 'E91: 3-1 (P:2 Key: 15)', 'B92: 8-4 (P:2 Key: 51)', 'E91: 4-1 (P:2 Key: 6)']
# Rotas: [[2, 5]]
# Rota atual trabalhada:  [2, 5]
# Rotas: [[2, 1, 0]]
# Rota atual trabalhada:  [2, 1, 0]
# Rotas: [[3, 0, 1]]
# Rota atual trabalhada:  [3, 0, 1]
# Rotas: [[8, 7, 4]]
# Rota atual trabalhada:  [8, 7, 4]
# Rotas: [[4, 1]]
# Rota atual trabalhada:  [4, 1]
# 3ª EXECUÇÃO:
# Requisições:  ['B92: 8-4 (P:2 Key: 8)']
# Requests ordenados por prioridade:  ['B92: 8-4 (P:2 Key: 8)']
# Rotas: [[8, 7, 4]]
# Rota atual trabalhada:  [8, 7, 4]
# Requests:  []
# Simulação:  2
# 1ª EXECUÇÃO:
# Requisições:  ['BB84: 4-2 (P:2 Key: 100)', 'E91: 3-6 (P:3 Key: 100)', 'B92: 0-3 (P:3 Key: 100)', 'BB84: 3-5 (P:4 Key: 100)', 'B92: 8-2 (P:5 Key: 100)']
# Requests ordenados por prioridade:  ['B92: 8-2 (P:5 Key: 100)', 'BB84: 3-5 (P:4 Key: 100)', 'E91: 3-6 (P:3 Key: 100)', 'B92: 0-3 (P:3 Key: 100)', 'BB84: 4-2 (P:2 Key: 100)']
# Rotas: [[8, 5, 2]]
# Rota atual trabalhada:  [8, 5, 2]
# Rotas: [[3, 4, 5]]
# Rota atual trabalhada:  [3, 4, 5]
# Rotas: [[3, 6]]
# Rota atual trabalhada:  [3, 6]
# Rotas: [[0, 3]]
# Rota atual trabalhada:  [0, 3]
# Rotas: [[4, 1, 2]]
# Rota atual trabalhada:  [4, 1, 2]
# 2ª EXECUÇÃO:
# Requisições:  ['BB84: 4-2 (P:2 Key: 18)', 'B92: 0-3 (P:3 Key: 43)', 'BB84: 3-5 (P:4 Key: 20)', 'B92: 8-2 (P:5 Key: 48)']
# Requests ordenados por prioridade:  ['B92: 8-2 (P:5 Key: 48)', 'BB84: 3-5 (P:4 Key: 20)', 'B92: 0-3 (P:3 Key: 43)', 'BB84: 4-2 (P:2 Key: 18)']
# Rotas: [[8, 5, 2]]
# Rota atual trabalhada:  [8, 5, 2]
# Rotas: [[3, 4, 5]]
# Rota atual trabalhada:  [3, 4, 5]
# Rotas: [[0, 3]]
# Rota atual trabalhada:  [0, 3]
# Rotas: [[4, 1, 2]]
# Rota atual trabalhada:  [4, 1, 2]
# Requests:  []
# Simulação:  3
# 1ª EXECUÇÃO:
# Requisições:  ['B92: 2-5 (P:3 Key: 100)', 'B92: 8-4 (P:2 Key: 100)', 'B92: 1-7 (P:5 Key: 100)', 'B92: 4-0 (P:1 Key: 100)', 'B92: 5-3 (P:1 Key: 100)']
# Requests ordenados por prioridade:  ['B92: 1-7 (P:5 Key: 100)', 'B92: 2-5 (P:3 Key: 100)', 'B92: 8-4 (P:2 Key: 100)', 'B92: 4-0 (P:1 Key: 100)', 'B92: 5-3 (P:1 Key: 100)']
# Rotas: [[1, 4, 7]]
# Rota atual trabalhada:  [1, 4, 7]
# Rotas: [[2, 5]]
# Rota atual trabalhada:  [2, 5]
# Rotas: [[8, 7, 4]]
# Rota atual trabalhada:  [8, 7, 4]
# Rotas: [[4, 3, 0]]
# Rota atual trabalhada:  [4, 3, 0]
# Rotas: [[5, 4, 3]]
# Rota atual trabalhada:  [5, 4, 3]
# 2ª EXECUÇÃO:
# Requisições:  ['B92: 2-5 (P:3 Key: 51)', 'B92: 8-4 (P:2 Key: 62)', 'B92: 1-7 (P:5 Key: 55)', 'B92: 4-0 (P:1 Key: 59)', 'B92: 5-3 (P:1 Key: 100)']
# Requests ordenados por prioridade:  ['B92: 1-7 (P:5 Key: 55)', 'B92: 2-5 (P:3 Key: 51)', 'B92: 8-4 (P:2 Key: 62)', 'B92: 4-0 (P:1 Key: 59)', 'B92: 5-3 (P:1 Key: 100)']
# Rotas: [[1, 4, 7]]
# Rota atual trabalhada:  [1, 4, 7]
# Rotas: [[2, 5]]
# Rota atual trabalhada:  [2, 5]
# Rotas: [[8, 7, 4]]
# Rota atual trabalhada:  [8, 7, 4]
# Rotas: [[4, 3, 0]]
# Rota atual trabalhada:  [4, 3, 0]
# Rotas: [[5, 4, 3]]
# Rota atual trabalhada:  [5, 4, 3]
# 3ª EXECUÇÃO:
# Requisições:  ['B92: 2-5 (P:3 Key: 5)', 'B92: 8-4 (P:2 Key: 19)', 'B92: 1-7 (P:5 Key: 6)', 'B92: 4-0 (P:1 Key: 10)', 'B92: 5-3 (P:1 Key: 100)']
# Requests ordenados por prioridade:  ['B92: 1-7 (P:5 Key: 6)', 'B92: 2-5 (P:3 Key: 5)', 'B92: 8-4 (P:2 Key: 19)', 'B92: 4-0 (P:1 Key: 10)', 'B92: 5-3 (P:1 Key: 100)']
# Rotas: [[1, 4, 7]]
# Rota atual trabalhada:  [1, 4, 7]
# Rotas: [[2, 5]]
# Rota atual trabalhada:  [2, 5]
# Rotas: [[8, 7, 4]]
# Rota atual trabalhada:  [8, 7, 4]
# Rotas: [[4, 3, 0]]
# Rota atual trabalhada:  [4, 3, 0]
# Rotas: [[5, 4, 3]]
# Rota atual trabalhada:  [5, 4, 3]
# 4ª EXECUÇÃO:
# Requisições:  ['B92: 5-3 (P:1 Key: 100)']
# Requests ordenados por prioridade:  ['B92: 5-3 (P:1 Key: 100)']
# Rotas: [[5, 4, 3]]
# Rota atual trabalhada:  [5, 4, 3]
# 5ª EXECUÇÃO:
# Requisições:  ['B92: 5-3 (P:1 Key: 47)']
# Requests ordenados por prioridade:  ['B92: 5-3 (P:1 Key: 47)']
# Rotas: [[5, 4, 3]]
# Rota atual trabalhada:  [5, 4, 3]
# 6ª EXECUÇÃO:
# Requisições:  ['B92: 5-3 (P:1 Key: 10)']
# Requests ordenados por prioridade:  ['B92: 5-3 (P:1 Key: 10)']
# Rotas: [[5, 4, 3]]
# Rota atual trabalhada:  [5, 4, 3]
# Requests:  []
# Simulação:  4
# 1ª EXECUÇÃO:
# Requisições:  ['BB84: 5-2 (P:5 Key: 100)', 'B92: 3-0 (P:5 Key: 100)', 'B92: 2-4 (P:1 Key: 100)', 'E91: 3-4 (P:2 Key: 100)', 'E91: 5-1 (P:2 Key: 100)']
# Requests ordenados por prioridade:  ['BB84: 5-2 (P:5 Key: 100)', 'B92: 3-0 (P:5 Key: 100)', 'E91: 3-4 (P:2 Key: 100)', 'E91: 5-1 (P:2 Key: 100)', 'B92: 2-4 (P:1 Key: 100)']
# Rotas: [[5, 2]]
# Rota atual trabalhada:  [5, 2]
# Rotas: [[3, 0]]
# Rota atual trabalhada:  [3, 0]
# Rotas: [[3, 4]]
# Rota atual trabalhada:  [3, 4]
# Rotas: [[5, 4, 1]]
# Rota atual trabalhada:  [5, 4, 1]
# Rotas: [[2, 1, 4]]
# Rota atual trabalhada:  [2, 1, 4]
# 2ª EXECUÇÃO:
# Requisições:  ['B92: 3-0 (P:5 Key: 60)', 'B92: 2-4 (P:1 Key: 43)', 'E91: 3-4 (P:2 Key: 3)']
# Requests ordenados por prioridade:  ['B92: 3-0 (P:5 Key: 60)', 'E91: 3-4 (P:2 Key: 3)', 'B92: 2-4 (P:1 Key: 43)']
# Rotas: [[3, 0]]
# Rota atual trabalhada:  [3, 0]
# Rotas: [[3, 4]]
# Rota atual trabalhada:  [3, 4]
# Rotas: [[2, 1, 4]]
# Rota atual trabalhada:  [2, 1, 4]
# 3ª EXECUÇÃO:
# Requisições:  ['B92: 3-0 (P:5 Key: 14)']
# Requests ordenados por prioridade:  ['B92: 3-0 (P:5 Key: 14)']
# Rotas: [[3, 0]]
# Rota atual trabalhada:  [3, 0]
# Requests:  []

# %%
print("Vazão média: ", np.mean(vazao))
print("Desvio padrão da vazão: ", np.std(vazao))
print("Taxa média: ", np.mean(taxa))
print("Desvio padrão da taxa: ", np.std(taxa))
# Out:
# Vazão média:  1.5
# Desvio padrão da vazão:  0.6236095644623236
# Taxa média:  0.315
# Desvio padrão da taxa:  0.0764925559195868
